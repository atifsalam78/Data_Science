# %%
import pandas as pd

# %%
file_path = r"C:\Users\atif\Dropbox\Data Science NED\Data Visualization\WhatsApp Chat with REG SOFTWARE JUNE 2023.txt"

# %%
msg = pd.read_csv(file_path, header=None, error_bad_lines=False, encoding='utf8')
# Out:
# C:\Users\atif\AppData\Local\Temp\ipykernel_9568\2522919310.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   msg = pd.read_csv(file_path, header=None, error_bad_lines=False, encoding='utf8')
# b'Skipping line 153: expected 4 fields, saw 5\nSkipping line 414: expected 4 fields, saw 5\n'

# %%
msg
# Out:
#             0                                                  1  \
# 0     6/17/23   10:18 PM - Messages and calls are end-to-end ...
# 1     6/17/23   10:07 PM - NED University - Khalid created gr...
# 2     6/17/23       10:18 PM - NED University - Khalid added you
# 3     6/17/23   10:19 PM - NED University - Khalid: <Media om...
# 4     6/17/23   10:21 PM - NED University - Khalid: Classes w...
# ..        ...                                                ...
# 616  10/25/23   6:04 PM - +92 312 8222812: Ok i will contact ...
# 617  10/25/23   6:26 PM - +92 317 2482228: Sir plz do somethi...
# 618  10/25/23               6:27 PM - +92 312 8222812: Ok i will
# 619  10/27/23   2:21 PM - +92 321 2109178: AOA. Sir bat hui k...
# 620  10/27/23   5:30 PM - +92 303 9086816: Sir ap unhy group ...
#
#                       2                                                3
# 0     not even WhatsApp   can read or listen to them. Tap to learn more.
# ...

# %%
msg.columns = ["date", "chat1", "chat2", "chat3"]

# %%
msg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    621 non-null    object
#  1   chat1   569 non-null    object
#  2   chat2   20 non-null     object
#  3   chat3   2 non-null      object
# dtypes: object(4)
# memory usage: 19.5+ KB

# %%
msg["date"] = pd.to_datetime(msg["date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2235         try:
# -> 2236             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2237             # If tzaware, these values represent unix timestamps, so we
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9568\2914558473.py in <module>
# ----> 1 msg["date"] = pd.to_datetime(msg["date"])
#
# ...

# %%
bol = msg.isnull()
bol

msg[["chat1", "chat2", "chat3"]] = msg[["chat1", "chat2", "chat3"]].fillna("None")

# %%
msg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7256 entries, 0 to 7255
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7256 non-null   object
#  1   chat1   7256 non-null   object
#  2   chat2   7256 non-null   object
#  3   chat3   7256 non-null   object
# dtypes: object(4)
# memory usage: 226.9+ KB

# %%
msg["date"] = pd.to_datetime(msg["date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2235         try:
# -> 2236             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2237             # If tzaware, these values represent unix timestamps, so we
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9568\2914558473.py in <module>
# ----> 1 msg["date"] = pd.to_datetime(msg["date"])
#
# ...

# %%
msg["combined"] = msg[["chat1", "chat2", "chat3"]].agg(" ".join, axis=1)

# %%
msg
# Out:
#           date                                              chat1  \
# 0       8/1/23   11:47 AM - Messages and calls are end-to-end ...
# 1      6/13/23   7:54 PM - NED University - Khalid created gro...
# 2      6/13/23   7:54 PM - New participants need admin approva...
# 3       8/1/23   11:47 AM - NED University - Khalid added you ...
# 4       8/1/23   12:00 PM - NED University - Khalid: Data Scie...
# ...        ...                                                ...
# 7251  10/25/23           11:01 AM - Azim NED PGD: <Media omitted>
# 7252  10/25/23                      12:11 PM - +92 331 2267022: a
# 7253  10/25/23            12:13 PM - Azim NED PGD: Same my answer
# 7254  10/25/23   12:14 PM - Azim NED PGD: In dict at time of i...
# 7255  10/25/23               12:16 PM - +92 331 2267022: okay...👍
#
#                    chat2                                            chat3  \
# 0      not even WhatsApp   can read or listen to them. Tap to learn more.
# ...

# %%
msg = msg.drop(labels=["chat1", "chat2", "chat3"], axis=1)

# %%
msg
# Out:
#           date                                           combined
# 0       8/1/23   11:47 AM - Messages and calls are end-to-end ...
# 1      6/13/23   7:54 PM - NED University - Khalid created gro...
# 2      6/13/23   7:54 PM - New participants need admin approva...
# 3       8/1/23   11:47 AM - NED University - Khalid added you ...
# 4       8/1/23   12:00 PM - NED University - Khalid: Data Scie...
# ...        ...                                                ...
# 7251  10/25/23   11:01 AM - Azim NED PGD: <Media omitted> None...
# 7252  10/25/23            12:11 PM - +92 331 2267022: a None None
# 7253  10/25/23   12:13 PM - Azim NED PGD: Same my answer  but ...
# 7254  10/25/23   12:14 PM - Azim NED PGD: In dict at time of i...
# 7255  10/25/23     12:16 PM - +92 331 2267022: okay...👍 None None
#
# [7256 rows x 2 columns]

# %%
msg["date"] = pd.to_datetime(msg["date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2235         try:
# -> 2236             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2237             # If tzaware, these values represent unix timestamps, so we
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9568\2914558473.py in <module>
# ----> 1 msg["date"] = pd.to_datetime(msg["date"])
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
msg["Text"] = message[1]
msg["Name"] = message[0]

# %%
msg=msg.drop(columns='chat1')
msg["Text"] = msg["Text"].str.lower()

# %%
msg["Text"] = msg["Text"].str.replace("<media omitted>","MediaShared")
msg["Text"] = msg["Text"].str.replace("this message was deleted","DeletedMsg")

# %%
msg
# Out:
#           date               chat2  \
# 0       8/1/23   not even WhatsApp
# 1      6/13/23                 NaN
# 2      6/13/23                 NaN
# 3       8/1/23                 NaN
# 4       8/1/23                 NaN
# ...        ...                 ...
# 7251  10/25/23                 NaN
# 7252  10/25/23                 NaN
# 7253  10/25/23     but I was wrong
# 7254  10/25/23           not float
# 7255  10/25/23                 NaN
#
#                                                 chat3  \
# 0      can read or listen to them. Tap to learn more.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 7251                                              NaN
# 7252                                              NaN
# ...

# %%
# !pip install whatsapp-converter
# Out:
# ...
#      -------------------------------------- 87.7/87.7 kB 330.9 kB/s eta 0:00:00
# ...
#      -------------------------------------- 44.2/44.2 kB 722.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 53.9/53.9 kB 126.8 kB/s eta 0:00:00
# ...

# %%
# !python whatsapp-converter.py -h
# Out:
# python: can't open file 'C:\Users\atif\Dropbox\Data Science NED\Data Visualization\whatsapp-converter.py': [Errno 2] No such file or directory

# %%
with open(file_path, "rb") as f:
    print(f.readlines())
# Out:
# [b'6/17/23, 10:18\xe2\x80\xafPM - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n', b'6/17/23, 10:07\xe2\x80\xafPM - NED University - Khalid created group "REG SOFTWARE JUNE 2023"\n', b'6/17/23, 10:18\xe2\x80\xafPM - NED University - Khalid added you\n', b'6/17/23, 10:19\xe2\x80\xafPM - NED University - Khalid: <Media omitted>\n', b'6/17/23, 10:21\xe2\x80\xafPM - NED University - Khalid: Classes will start from next week.\n', b'6/18/23, 4:36\xe2\x80\xafPM - NED University - Khalid added +92 332 1308489\n', b'6/18/23, 4:36\xe2\x80\xafPM - NED University - Khalid: Classes will start from next week.\n', b'6/18/23, 5:38\xe2\x80\xafPM - NED University - Khalid added +92 321 3101227\n', b'6/19/23, 11:46\xe2\x80\xafAM - NED University - Khalid added +92 313 2012060\n', b'6/19/23, 12:00\xe2\x80\xafPM - NED University - Khalid added +92 303 9139498\n', b'6/20/23, 5:23\xe2\x80\xafPM - NED University -
# ...
