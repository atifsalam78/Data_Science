# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bike = pd.read_csv("bikeshare/day.csv")
bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
plt.scatter(bike.workingday, bike.casual)
plt.show()

# %%
plt.scatter(bike.workingday, bike.registered)
plt.show()

# %%
bike.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
bike.dteday = pd.to_datetime(bike.dteday)
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
bike.shape
# Out:
# (731, 16)

# %%
bike[bike["workingday"]==0]
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 7          8 2011-01-08       1   0     1        0        6           0
# 8          9 2011-01-09       1   0     1        0        0           0
# 14        15 2011-01-15       1   0     1        0        6           0
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 721      722 2012-12-22       1   1    12        0        6           0
# 722      723 2012-12-23       1   1    12        0        0           0
# 724      725 2012-12-25       1   1    12        1        2           0
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
bike[bike.workingday == 0]
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 7          8 2011-01-08       1   0     1        0        6           0
# 8          9 2011-01-09       1   0     1        0        0           0
# 14        15 2011-01-15       1   0     1        0        6           0
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 721      722 2012-12-22       1   1    12        0        6           0
# 722      723 2012-12-23       1   1    12        0        0           0
# 724      725 2012-12-25       1   1    12        1        2           0
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
pd.pivot_table(bike, index="workingday", values=["casual", "registered"], aggfunc="mean" )
# Out:
#                  casual   registered
# workingday
# 0           1371.134199  2959.034632
# 1            606.570000  3978.250000

# %%
pd.pivot_table(bike, index=["yr","workingday"], values=["casual", "registered"], aggfunc="mean" )
# Out:
#                     casual   registered
# yr workingday
# 0  0           1120.852174  2242.965217
#    1            473.416000  2951.640000
# 1  0           1619.258621  3668.931034
#    1            739.724000  5004.860000

# %%
pd.pivot_table(bike, index=["dteday","weekday"], values=["casual", "registered"], aggfunc="mean" )
# Out:
#                     casual  registered
# dteday     weekday
# 2011-01-01 6           331         654
# 2011-01-02 0           131         670
# 2011-01-03 1           120        1229
# 2011-01-04 2           108        1454
# 2011-01-05 3            82        1518
# ...                    ...         ...
# 2012-12-27 4           247        1867
# 2012-12-28 5           644        2451
# 2012-12-29 6           159        1182
# 2012-12-30 0           364        1432
# 2012-12-31 1           439        2290
#
# [731 rows x 2 columns]

# %%
bike[bike["workingday"]==0][["casual", "registered"]].mean()
# Out:
# casual        1371.134199
# registered    2959.034632
# dtype: float64

# %%
work_day_mean = pd.pivot_table(bike, index="workingday", values=["casual", "registered"], aggfunc="mean")

# %%
work_day_mean
# Out:
#                  casual   registered
# workingday
# 0           1371.134199  2959.034632
# 1            606.570000  3978.250000

# %%
type(work_day_mean)
# Out:
# pandas.core.frame.DataFrame

# %%
# Ploting using pandas
work_day_mean["casual"].plot.bar()
plt.show()

# %%
work_day_mean["casual"].plot.bar()
plt.xticks(rotation = 0)
plt.show()

# %%
work_day_mean["casual"].plot.bar()
plt.xticks(ticks=[0,1], labels=["Holiday", "Working Day"], rotation = 0)
plt.show()

# %%
bike.weekday.unique()
# Out:
# array([6, 0, 1, 2, 3, 4, 5], dtype=int64)

# %%
bike[["dteday", "weekday"]]
# Out:
#         dteday  weekday
# 0   2011-01-01        6
# 1   2011-01-02        0
# 2   2011-01-03        1
# 3   2011-01-04        2
# 4   2011-01-05        3
# ..         ...      ...
# 726 2012-12-27        4
# 727 2012-12-28        5
# 728 2012-12-29        6
# 729 2012-12-30        0
# 730 2012-12-31        1
#
# [731 rows x 2 columns]

# %%
bike["dteday"].dt.strftime("%A %B")
# Out:
# 0       Saturday January
# 1         Sunday January
# 2         Monday January
# 3        Tuesday January
# 4      Wednesday January
#              ...
# 726    Thursday December
# 727      Friday December
# 728    Saturday December
# 729      Sunday December
# 730      Monday December
# Name: dteday, Length: 731, dtype: object

# %%
pd.options.display.max_rows = None

# %%
bike[bike["workingday"] == 0]
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 7          8 2011-01-08       1   0     1        0        6           0
# 8          9 2011-01-09       1   0     1        0        0           0
# 14        15 2011-01-15       1   0     1        0        6           0
# 15        16 2011-01-16       1   0     1        0        0           0
# 16        17 2011-01-17       1   0     1        1        1           0
# 21        22 2011-01-22       1   0     1        0        6           0
# 22        23 2011-01-23       1   0     1        0        0           0
# 28        29 2011-01-29       1   0     1        0        6           0
# 29        30 2011-01-30       1   0     1        0        0           0
# 35        36 2011-02-05       1   0     2        0        6           0
# ...

# %%
week_group = bike.groupby("weekday")
week_group.groups
# Out:
# {0: [1, 8, 15, 22, 29, 36, 43, 50, 57, 64, 71, 78, 85, 92, 99, 106, 113, 120, 127, 134, 141, 148, 155, 162, 169, 176, 183, 190, 197, 204, 211, 218, 225, 232, 239, 246, 253, 260, 267, 274, 281, 288, 295, 302, 309, 316, 323, 330, 337, 344, 351, 358, 365, 372, 379, 386, 393, 400, 407, 414, 421, 428, 435, 442, 449, 456, 463, 470, 477, 484, 491, 498, 505, 512, 519, 526, 533, 540, 547, 554, 561, 568, 575, 582, 589, 596, 603, 610, 617, 624, 631, 638, 645, 652, 659, 666, 673, 680, 687, 694, ...], 1: [2, 9, 16, 23, 30, 37, 44, 51, 58, 65, 72, 79, 86, 93, 100, 107, 114, 121, 128, 135, 142, 149, 156, 163, 170, 177, 184, 191, 198, 205, 212, 219, 226, 233, 240, 247, 254, 261, 268, 275, 282, 289, 296, 303, 310, 317, 324, 331, 338, 345, 352, 359, 366, 373, 380, 387, 394, 401, 408, 415, 422, 429, 436, 443, 450, 457, 464, 471, 478, 485, 492, 499, 506, 513, 520, 527, 534, 541, 548, 555, 562, 569, 576, 583, 590, 597, 604, 611, 618, 625, 632, 639, 646, 653, 660, 667, 674, 681, 688, 695, ...], 2: [3, 10,
# ...

# %%
week_group.groups.keys()
# Out:
# dict_keys([0, 1, 2, 3, 4, 5, 6])

# %%
week_group.get_group(5)
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 6          7 2011-01-07       1   0     1        0        5           1
# 13        14 2011-01-14       1   0     1        0        5           1
# 20        21 2011-01-21       1   0     1        0        5           1
# 27        28 2011-01-28       1   0     1        0        5           1
# 34        35 2011-02-04       1   0     2        0        5           1
# 41        42 2011-02-11       1   0     2        0        5           1
# 48        49 2011-02-18       1   0     2        0        5           1
# 55        56 2011-02-25       1   0     2        0        5           1
# 62        63 2011-03-04       1   0     3        0        5           1
# 69        70 2011-03-11       1   0     3        0        5           1
# 76        77 2011-03-18       1   0     3        0        5           1
# 83        84 2011-03-25       2   0     3        0        5           1
# ...

# %%
week = week_group[["casual", "registered"]].mean()
week
# Out:
#               casual   registered
# weekday
# 0        1338.295238  2890.533333
# 1         674.133333  3663.990476
# 2         556.182692  3954.480769
# 3         551.144231  3997.394231
# 4         590.961538  4076.298077
# 5         752.288462  3938.000000
# 6        1465.257143  3085.285714

# %%
week["registered"].plot.bar()
plt.show()

# %%
week["registered"].plot.bar()
plt.xticks(ticks=[0,1,2,3,4,5,6], labels=["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"], rotation = 40)
plt.show()

# %%
week["registered"].plot.barh()
plt.xticks(rotation = 40)
plt.show()
